# %% [markdown]
# # Interceptor

# %%
# %matplotlib widget
import requests
with open("interceptor.py", 'w') as foo:
     foo.write(requests.get("https://raw.githubusercontent.com/bbadzioch/MTH309_S2025/main/notebooks/interceptor.py").text)
from interceptor import *
x=interceptor()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
